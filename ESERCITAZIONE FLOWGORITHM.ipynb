# %%
print("Ciao, calcolo l'area del quadrato, dammi il lato:")
l = float(input())
if l > 0:
    print("Calcolo l'area del quadrato:")
    a = l ** 2
    print("Il risultato è: ")
    print(a)
else:
    print("L'area del quadrato deve essere maggiore di 0. Fai ripartire il programma.")
# Out:
# Ciao, calcolo l'area del quadrato, dammi il lato:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 100421.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("Ciao, calcolo l'area del quadrato, dammi il lato:")
l = float(input())
while l <= 0:
    print("L'area del quadrato deve essere maggiore di 0. Riscrivi l:")
    l = float(input())
print("Calcolo l'area del quadrato:")
a = l ** 2
print("Il risultato è: ")
print(a)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 103842.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("Ciao, calcolo l'area del quadrato, dammi il lato:")
l = float(input())
print("Calcolo l'area del quadrato.")
a = l ** 2
print("Il risultato è: ")
print(a)
# Out:
# Ciao, calcolo l'area del quadrato, dammi il lato:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 104204.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("dimmi su che PIN vuoi attaccare il LED")
lED = int(input())
print("dimmi la modalità del PIN LED, digita TRUE per OUTPUT")
pinmodeLED = (input().lower == 'true')
print("dimmi su che PIN vuoi attaccare il bottone")
pushbutton = int(input())
print("dimmi la modalità del PINBUTTON digita TRUE per OUTPUT")
pinBUTTON = input()
while 1 == 1:
    print("premi TRUE per accendere LED")
    buttonstate = (input().lower == 'true')
    if buttonstate == True:
        ledstate = True
        print(ledstate)
    else:
        ledstate = False
        print(ledstate)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 105142.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("Ciao, seleziona Q per il quadrato e T per il triangolo:")
scelta = input()
if scelta == "Q":
    print("Inserisci il valore del lato:")
    l = float(input())
    while l <= 0:
        print("Il valore del lato deve essere maggiore a 0. Riscrivi il valore:")
        l = float(input())
    a = l ** 2
else:
    if scelta == "T":
        print("Inserisci il valore della base:")
        b = float(input())
        while b <= 0:
            print("Il valore della base deve essere maggiore a 0. Riscrivi il valore:")
            b = float(input())
        print("Ora inserisci il valore dell'altezza:")
        h = float(input())
        while h <= 0:
            print("Il valore dell'altezza deve essere maggiore a 0. Riscrivi il valore:")
            h = float(input())
        a = b * h / 2
    else:
        print("Devi scegliere tra Q, per il quadrato, e T, per il triangolo.")
        a = 0
print("L'area della figura scelta è:")
print(a)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 105707.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("ciao seleziona per quadrato e t per il triangolo")
scelta = input()
if scelta == "q":
    print("ciao calcolo l'area del quadrato dando il lato")
    l = float(input())
    while l <= 0:
        print("insulto")
        l = float(input())
    a = l ** 2
else:
    if scelta == "l":
        print("ciao calcola l'area del triangolo dandomi la base")
        b = float(input())
        while h <= 0:
            print("insulto")
            h = float(input())
        print("dammi l'altezza")
        h = float(input())
        a = b * h / 2
    else:
        print("ho detto q o t coglione")
        a = 0
print("il valore dell'area è: ")
print("A")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 110055.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
import random
random.seed()   #Prepare random number generator

print("Ciao, seleziona tra: Carta; Forbice o Sasso o Esci.")
scelta = input()
while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
    print("Mi sembra di aver detto che le opzioni fossero: Carta; Forbice; e Sasso... Rifai la scelta.")
    scelta = input()
if scelta == "esci":
numero = int(random.random() * 2)
while scelta != "esci":
    if numero == 0:
        computer = "carta"
    else:
        if numero == 1:
            computer = "sasso"
        else:
            computer = "forbice"
    if scelta == "carta" and computer == "sasso" or scelta == "forbice" and computer == "carta" or scelta == "sasso" and computer == "forbice":
        print(computer)
        print("Hai vinto!")
    else:
        if scelta == "sasso" and computer == "sasso" or scelta == "forbice" and computer == "forbice" or scelta == "carta" and computer == "carta":
            print(computer)
            print("Pareggio!")
        else:
            print(computer)
            print("Hai perso!...")
    print("Ciao, seleziona tra: Carta; Forbice o Sasso o Esci.")
    scelta = input()
    while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
        print("Mi sembra di aver detto che le opzioni fossero: Carta; Forbice; e Sasso... Rifai la scelta.")
        scelta = input()
    if scelta == "esci":
    numero = int(random.random() * 2)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 110553.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
import random
random.seed()   #Prepare random number generator

print("Ciao, seleziona tra: Carta; Forbice o Sasso o Esci.")
scelta = input()
while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
    print("Mi sembra di aver detto che le opzioni fossero: Carta; Forbice; e Sasso... Rifai la scelta.")
    scelta = input()
if scelta == "esci":
numero = int(random.random() * 2)
while scelta != "esci":
    if numero == 0:
        computer = "carta"
    else:
        if numero == 1:
            computer = "sasso"
        else:
            computer = "forbice"
    if scelta == "carta" and computer == "sasso" or scelta == "forbice" and computer == "carta" or scelta == "sasso" and computer == "forbice":
        print(computer)
        print("Hai vinto!")
    else:
        if scelta == "sasso" and computer == "sasso" or scelta == "forbice" and computer == "forbice" or scelta == "carta" and computer == "carta":
            print(computer)
            print("Pareggio!")
        else:
            print(computer)
            print("Hai perso!...")
    print("Ciao, seleziona tra: Carta; Forbice o Sasso o Esci.")
    scelta = input()
    while scelta != "carta" and scelta != "forbice" and scelta != "sasso" and scelta != "esci":
        print("Mi sembra di aver detto che le opzioni fossero: Carta; Forbice; e Sasso... Rifai la scelta.")
        scelta = input()
    if scelta == "esci":
    numero = int(random.random() * 2)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 110751.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("dammi un numero")
numero = int(input())
if numero > 0:
    print("il numero e meggiore di zero")
else:
    if numero == 0:
        print("il numero è zero")
    else:
        print("il numero e minonore di zero")
if numero % 2 == 0:
    print("il numero e pari")
else:
    print("il numero e dispari")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 111053.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("Dammi un numero:")
numero = int(input())
if numero > 0:
    print("Il numero dato è maggiore di 0.")
else:
    if numero == 0:
        print("Il numero dato è 0.")
    else:
        print("Il numero dato è minore di 0.")
if numero % 2 == 0:
    print("Il numero dato è pari.")
else:
    print("Il numero dato è dispari.")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 111303.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("ciao, calcolo area del quadrato dammi il lato")
l = float(input())
while l <= 0:
    print("scemo, coglione")
    l = float(input())
print("calcolo, l'area del quadrato")
a = l ** 2
print("il risultato è: ")
print(a)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 111611.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
lista = [0] * (3)
quadrati = [0] * (3)

print("ciao, dammi tre valori dei quali vuoi i quadrati")
for i in range(0, 2 + 1, 1):
    lista[i] = int(input())
print("calcola i quadrati degli elementi della lista")
for i in range(0, 2 + 1, 1):
    quadrati[i] = lista[i] ** 2
    print("lista[i]")
    print("quadrati[i]")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 111845.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
import random
random.seed()   #Prepare random number generator

vittorie = 0
pareggi = 0
sconfitte = 0
print("Ciao, scegli carta, forbice o sasso oppure esci:")
scelta = input()
while scelta != "sasso" and scelta != "carta" and scelta != "carta" and scelta != "esci":
    print("Devi scegliere tra sasso, carta o forbice. Scegli di nuovo:")
    scelta = input()
if scelta == "esci":
for i in range(0, 999999 + 1, 1):
    numero = int(random.random() * 3)
    if numero == 0:
        computer = "carta"
    else:
        if numero == 1:
            computer = "forbice"
        else:
            computer = "sasso"
    if scelta == "carta" and computer == "sasso" or scelta == "forbice" and computer == "carta" or scelta == "sasso" and computer == "forbice":
        vittorie = vittorie + 1
    else:
        if scelta == "carta" and computer == "carta" or scelta == "forbice" and computer == "forbice" or scelta == "sasso" and computer == "sasso":
            pareggi = pareggi + 1
        else:
            sconfitte = sconfitte + 1
print("Numero vittorie: ")
print(vittorie)
print("Numero pareggi: ")
print(pareggi)
print("Numero sconfitte: ")
print(sconfitte)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 112554.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
import random
random.seed()   #Prepare random number generator

print("Ciao, scegli carta, forbice o sasso oppure esci:")
scelta = input()
while scelta != "sasso" and scelta != "carta" and scelta != "carta" and scelta != "esci":
    print("Devi scegliere tra sasso, carta o forbice. Scegli di nuovo:")
    scelta = input()
if scelta == "esci":
while scelta != "esci":
    numero = int(random.random() * 2)
    if numero == 0:
        computer = "carta"
    else:
        if numero == 1:
            computer = "forbice"
        else:
            computer = "sasso"
    if scelta == "carta" and computer == "sasso" or scelta == "forbice" and computer == "carta" or scelta == "sasso" and computer == "forbice":
        print(computer)
        print("Hai vinto!")
    else:
        if scelta == "carta" and computer == "carta" or scelta == "forbice" and computer == "forbice" or scelta == "sasso" and computer == "sasso":
            print(computer)
            print("Hai pareggiato")
        else:
            print(computer)
            print("Hai perso")
    print("Ciao, scegli carta, forbice o sasso oppure esci:")
    scelta = input()
    while scelta != "sasso" and scelta != "carta" and scelta != "carta" and scelta != "esci":
        print("Devi scegliere tra sasso, carta o forbice. Scegli di nuovo:")
        scelta = input()
    if scelta == "esci":

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 112901.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
print("Dimmi su chhe PIN vuoi attaccare il LED:")
lED = int(input())
print("Dimmi la modalità del PIN. Digita TRUE per OUTPUT:")
pinmodeLED = (input().lower == 'true')
print("Dimmi su chhe PIN vuoi attaccare il bottone: ")
pushbutton = int(input())
print("Dimmi la modalità del PINBUTTON. Digita TRUE per OUTPUT:")
pinmodebutton = (input().lower == 'true')
while 1 == 1:
    print("Digita TRUE per accendere il LED")
    buttonstate = (input().lower == 'true')
    if buttonstate == True:
        ledstate = True
        print(ledstate)
    else:
        if buttonstate == False:
            ledstate = False
            print(ledstate)
        else:
            print("Devi scrivere TRUE o FALSE")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 113350.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()

# %%
ledPins = [0] * (5)
ledStates = [False] * (5)

ledcount = 5
for i in range(0, ledcount - 1 + 1, 1):
    print("dimmi i PIN al quale attaccare i LED")
    ledPins[i] = int(input())
    ledState[i] = False
for i in range(0, ledcount - 1 + 1, 1):
    print("dimmi i PIN al quale attaccare i LED")
    pinmode[i] = input()
while 1 == 1:
    print("dimmi il livello corrispondente del potenziometro")
    livelli = int(input())
    ledlevel = float(livelli * ledcount) / 1023
    print("il livello è")
    print(ledlevel)
    for thisLed in range(0, ledcount - 1 + 1, 1):
        if thisLed < ledlevel:
            ledState[thisLed] = True
        else:
            ledStates[thisLed] = False
        print(ledStates[thisLed])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('C:/Users/User/OneDrive/Immagini/Catture di schermata/Screenshot 2024-11-08 113641.png')
plt.imshow(img)
plt.axis('off')  # Per nascondere gli assi
plt.show()
